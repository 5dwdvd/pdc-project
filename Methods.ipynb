# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pdc_project import plot

# %%
df = pd.read_excel("out/foptd_plot.xlsx")

# %%
sns.lineplot(df, x = 'Time', y = 'EthanolConc')
ax2 = plt.twinx()
sns.lineplot(df, x = 'Time', y = 'EthanolConcDerivative', ax = ax2)
# Out:
# <AxesSubplot: xlabel='Time', ylabel='EthanolConcDerivative'>
